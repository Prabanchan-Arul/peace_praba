# %%
import pandas as pd

# %%
data= {
    'Name':['keerthana','sakthi','prabanchan','sajini','sandeep','kusum','dhanush','swetha','madhavan','aasha'],
    'Age':[21,22,20,21,23,22,20,20,20,19],
    'City':['cuddalore','bangalore','cuddalore','putlur','ambur','rajasthan','tirutani','tirutani','ariyalur','bangalore'],
    'gender':['female','male','male','female','male','female','male','female','male','female'],
    'qualification':['b.tech','b.tech','b.tech','b.tech','b.tech','b.tech','b.tech','b.tech','b.tech','b.tech'],
    'salary':[25000,30000,30000,40000,35000,40000,30000,50000,35000,25000]

}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#          Name  Age       City  gender qualification  salary
# 0   keerthana   21  cuddalore  female        b.tech   25000
# 1      sakthi   22  bangalore    male        b.tech   30000
# 2  prabanchan   20  cuddalore    male        b.tech   30000
# 3      sajini   21     putlur  female        b.tech   40000
# 4     sandeep   23      ambur    male        b.tech   35000
# 5       kusum   22  rajasthan  female        b.tech   40000
# 6     dhanush   20   tirutani    male        b.tech   30000
# 7      swetha   20   tirutani  female        b.tech   50000
# 8    madhavan   20   ariyalur    male        b.tech   35000
# 9       aasha   19  bangalore  female        b.tech   25000

# %%
df.tail(4)
# Out:
#        Name  Age       City  gender qualification  salary
# 6   dhanush   20   tirutani    male        b.tech   30000
# 7    swetha   20   tirutani  female        b.tech   50000
# 8  madhavan   20   ariyalur    male        b.tech   35000
# 9     aasha   19  bangalore  female        b.tech   25000

# %%
df.head(3)
# Out:
#          Name  Age       City  gender qualification  salary
# 0   keerthana   21  cuddalore  female        b.tech   25000
# 1      sakthi   22  bangalore    male        b.tech   30000
# 2  prabanchan   20  cuddalore    male        b.tech   30000

# %%
df.shape
# Out:
# (10, 6)

# %%
df.size
# Out:
# 60

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'gender', 'qualification', 'salary'], dtype='object')

# %%
df.columns.values
# Out:
# array(['Name', 'Age', 'City', 'gender', 'qualification', 'salary'],
#       dtype=object)

# %%
column_name=df.columns[2]

# %%
print(column_name)
# Out:
# City

# %%
res=sorted(df.columns)

# %%
print(res)
# Out:
# ['Age', 'City', 'Name', 'gender', 'qualification', 'salary']

# %%
data=pd.read_csv('/student_performance.csv')

# %%
data
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male              85                 15
# 1          2     Sarah  Female              90                 20
# 2          3      Alex    Male              78                 10
# 3          4   Michael    Male              92                 25
# 4          5      Emma  Female              88                 18
# 5          6    Olivia  Female              95                 30
# 6          7    Daniel    Male              70                  8
# 7          8    Sophia  Female              85                 17
# 8          9     James    Male              82                 12
# 9         10  Isabella  Female              91                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0             78                          1            High          80
# 1             85                          2          Medium          87
# ...

# %%
data.head(3)
# Out:
#    StudentID   Name  Gender  AttendanceRate  StudyHoursPerWeek  PreviousGrade  \
# 0          1   John    Male              85                 15             78
# 1          2  Sarah  Female              90                 20             85
# 2          3   Alex    Male              78                 10             65
#
#    ExtracurricularActivities ParentalSupport  FinalGrade
# 0                          1            High          80
# 1                          2          Medium          87
# 2                          0             Low          68

# %%
data.tail(2)
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 8          9     James    Male              82                 12
# 9         10  Isabella  Female              91                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 8             70                          2             Low          72
# 9             86                          3            High          88

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10 non-null     int64
#  1   Name                       10 non-null     object
#  2   Gender                     10 non-null     object
#  3   AttendanceRate             10 non-null     int64
#  4   StudyHoursPerWeek          10 non-null     int64
#  5   PreviousGrade              10 non-null     int64
#  6   ExtracurricularActivities  10 non-null     int64
#  7   ParentalSupport            10 non-null     object
#  8   FinalGrade                 10 non-null     int64
# dtypes: int64(6), object(3)
# memory usage: 852.0+ bytes

# %%
data.shape
# Out:
# (10, 9)

# %%
data.size
# Out:
# 90

# %%
data.AttendanceRate
# Out:
# 0    85
# 1    90
# 2    78
# 3    92
# 4    88
# 5    95
# 6    70
# 7    85
# 8    82
# 9    91
# Name: AttendanceRate, dtype: int64

# %%
data.columns
# Out:
# Index(['StudentID', 'Name', 'Gender', 'AttendanceRate', 'StudyHoursPerWeek',
#        'PreviousGrade', 'ExtracurricularActivities', 'ParentalSupport',
#        'FinalGrade'],
#       dtype='object')

# %%
data.columns.values
# Out:
# array(['StudentID', 'Name', 'Gender', 'AttendanceRate',
#        'StudyHoursPerWeek', 'PreviousGrade', 'ExtracurricularActivities',
#        'ParentalSupport', 'FinalGrade'], dtype=object)

# %%
data.columns[5]
# Out:
# 'PreviousGrade'

# %%
d=sorted(data.columns)

# %%
print(d)
# Out:
# ['AttendanceRate', 'ExtracurricularActivities', 'FinalGrade', 'Gender', 'Name', 'ParentalSupport', 'PreviousGrade', 'StudentID', 'StudyHoursPerWeek']

# %%
data.describe()
# Out:
#        StudentID  AttendanceRate  StudyHoursPerWeek  PreviousGrade  \
# count   10.00000       10.000000          10.000000      10.000000
# mean     5.50000       85.600000          17.700000      78.100000
# std      3.02765        7.441625           6.848357      10.170218
# min      1.00000       70.000000           8.000000      60.000000
# 25%      3.25000       82.750000          12.750000      71.750000
# 50%      5.50000       86.500000          17.500000      80.000000
# 75%      7.75000       90.750000          21.500000      85.750000
# max     10.00000       95.000000          30.000000      90.000000
#
#        ExtracurricularActivities  FinalGrade
# count                  10.000000   10.000000
# mean                    1.500000   80.200000
# std                     1.080123   10.097304
# min                     0.000000   62.000000
# 25%                     1.000000   73.500000
# 50%                     1.500000   82.500000
# ...

# %%
data.isnull().sum()
# Out:
# StudentID                    0
# Name                         0
# Gender                       0
# AttendanceRate               0
# StudyHoursPerWeek            0
# PreviousGrade                0
# ExtracurricularActivities    0
# ParentalSupport              0
# FinalGrade                   0
# dtype: int64

# %%
data=pd.read_csv('/student_performance.csv')

# %%
data
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male              85                 15
# 1          2     Sarah  Female              90                 20
# 2          3      Alex    Male              78                 10
# 3          4   Michael    Male              92                 25
# 4          5      Emma  Female              88                 18
# 5          6    Olivia  Female              95                 30
# 6          7    Daniel    Male              70                  8
# 7          8    Sophia  Female              85                 17
# 8          9     James    Male              82                 12
# 9         10  Isabella  Female              91                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade   Age
# 0             78                          1            High          80  23.0
# 1             85                          2          Medium          87  33.0
# ...

# %%
data.isnull().sum()
# Out:
# StudentID                    0
# Name                         0
# Gender                       0
# AttendanceRate               0
# StudyHoursPerWeek            0
# PreviousGrade                0
# ExtracurricularActivities    0
# ParentalSupport              0
# FinalGrade                   0
# Age                          3
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# StudentID                    0
# Name                         0
# Gender                       0
# AttendanceRate               0
# StudyHoursPerWeek            0
# PreviousGrade                0
# ExtracurricularActivities    0
# ParentalSupport              0
# FinalGrade                   0
# Age                          0
# dtype: int64
