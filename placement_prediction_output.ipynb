# %%
import pickle as pk


with open('/content/drive/MyDrive/placemnt_model.pkl', 'rb') as file:
  predict=pk.load(file)

# %%
my_prediction = predict.predict([[100,9,8,1,8,10,5]])
print(my_prediction)
# Out:
# [1]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
