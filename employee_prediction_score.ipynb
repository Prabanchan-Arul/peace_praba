# %% [markdown]
# <a href="https://colab.research.google.com/github/Prabanchan-Arul/peace_praba/blob/main/employee_prediction_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle

# %%
with open ('/content/drive/MyDrive/model.pkl','rb') as f:
    mp = pickle.load(f)

# %%
prediction = mp.predict([[1,3,5,6,7,8,0,3]])

# %%
print(prediction)
# Out:
# [0.95474543]
